# %%
import matplotlib.pyplot as plt;

# %%
y1 = [86, 84, 83, 82, 80 ,79 ,78 ,77 ,76 ,76,76 ,75 ,74 ,73 ,72,72 ,70 ,69]
y2 = [94, 92 ,90 ,88 ,86 ,84 ,82 ,80 ,79 ,78 ,76 ,76 ,76 ,75 ,75 ,75 ,75 ,74 ,74 ,74 ,73 ,72 ,72 ,72 ]
t2 =  [0 , 20 ,40 ,60 ,80 ,100,120,140 ,160 ,180 ,200 ,220 ,240 ,260 ,280 , 300 ,320 ,340 ,360 ,380 ,400 ,420 ,440 ,460]
t1 = [0 , 20 ,40 ,60 ,80 ,100,120,140 ,160 ,180 ,200 ,220 ,240 ,260 ,280 , 300 ,320 ,340 ]

# %%
plt.plot(t1, y1, 'r',label='naphthalene')
plt.plot(t2, y2, 'b',label='mix')
plt.legend(loc='best', ncol=2)
